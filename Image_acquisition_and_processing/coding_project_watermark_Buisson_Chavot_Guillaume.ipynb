# %% [markdown]
# <center> <h1>INFO-H500 - Image acquisition and processing - </h1> </center>
#
# <center> <h2>Assignment 1: Coding Project - Watermark</h2> </center>
#
# <center> <h3>Guillaume Buisson-Chavot</h3> </center>
# <center> <h3>matricule: 000465822 </h3> </center>

# %%
import numpy as np
from matplotlib import pyplot as plt
from skimage.color import gray2rgba
# %matplotlib notebook
from skimage.io import imread, imshow, imsave

im = imread('etretat.jpg')
plt.figure()
imshow(im)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
im2 = imread('watermark.png')
plt.figure()
imshow(im2)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def watermark(imref,watermark, xcoord=500, ycoord = 400, watermark_shade = 50):
    if xcoord > imref.shape[1]-watermark.shape[1] or ycoord > imref.shape[0]-watermark.shape[0]:
        print("error, watermark is out of range!")
    else:
        im_final = imref.copy() 
        mask = (watermark == 255)
        im_m= imref[ycoord:watermark.shape[0]+ycoord,xcoord:watermark.shape[1]+xcoord]
        im_m[mask == True] = watermark_shade
        xc,yc = -1,0
        for x in range(xcoord,im_m.shape[1]+xcoord):
            xc += 1
            yc=0
            for y in range(ycoord,im_m.shape[0]+ycoord):
                im_final[y,x]= im_m[yc,xc]
                yc+=1
        return im_final        
            
            
im_final= watermark(im,im2) 

plt.figure()
imshow(im_final)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
imsave("recorded_image.jpg",im_final)
